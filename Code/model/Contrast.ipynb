# %% [markdown]
# ## Visualizing Contrast between Two Experiments

# %% [markdown]
# ### Import package

# %%
import json
import numpy as np

from pathlib import Path

from matplotlib import pyplot as plt

# %% [markdown]
# ### Load composite structure for the two experiments

# %%
INPUT_DIR: Path = Path("/home/b11209013/Manuscript_Prep/KW_CRI/File")

# Load NoRad experiments
with open(INPUT_DIR / "NoRad_Composite.json", "r", encoding="utf-8") as norad_f:
    content = norad_f.read().strip()
    norad_composite = json.loads(content) if content else {}

print(norad_composite)
# Out:
# {}
